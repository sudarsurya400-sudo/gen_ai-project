# %% [markdown]
# <a href="https://colab.research.google.com/github/sudarsurya400-sudo/gen_ai-project/blob/main/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# from transformers import pipeline
#
# pipe = pipeline("text-generation", model="ibm-granite/granite-3.3-2b-instruct")
# messages = [
#     {"role": "user", "content": "Who are you?"},
# ]
# pipe(messages)
